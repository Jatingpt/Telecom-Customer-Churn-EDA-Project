# %% [markdown]
# <a href="https://colab.research.google.com/github/Jatingpt/Telecom-Customer-Churn-EDA-Project/blob/main/Telecom_Customer_Churn_EDA_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**You are a Data Analyst at a leading telecommunications company. The company has been experiencing an increased churn rate, i.e., customers switching to other service providers. This churn is impacting the company’s revenue and market share.**
#
# ##                     **Context**
# ##**The company wants to leverage data analyizing to understand the problem better and devise strategies to effectively retain customers. You have been provided with a dataset of past customers’ behavior and demographics, along with whether they churned or not.**
#
#
# ##**"Predict behavior to retain customers. Also can analyze all relevant customer data and develop focused customer retention programs."**
#
# ##**Business Objective is-**
#
# ##**1. Analyze customer data to understand reason for churn and who could be the next**
#
# ##**2. Potential customer to leave the company ?**
#
# ##**3. What contributes to the higher churn rate of customer and what could be some of the probable solution to address the same ?**

# %% [markdown]
# ##**Content**
# ###**Each row represents a customer, each column contains customer’s attributes described on the column Metadata.**

# %% [markdown]
# ##**About the Dataset.**
#
# **The data set includes information about:**
#
# **Customers who left within the last month – the column is called Churn
# Services that each customer has signed up for – phone, multiple lines, internet, online security, online backup, device protection, tech support, and streaming TV and movies
# Customer account information – how long they’ve been a customer, contract, payment method, paperless billing, monthly charges, and total charges
# Demographic info about customers – gender, age range, and if they have partners and dependents**
#
# **Each row represents a customer, each column contains customer’s attributes described on the column Metadata.**
#
# **The raw data contains 7043 rows (customers) and 21 columns (features).**

# %% [markdown]
# ##**Approach used.**
#
# The approach we have used in this project is defined in the given format-
#
# 1) **Loading our data :** In this section we just loaded our dataset in colab notebook and read the csv file.
#
# 2) **Inspecting the data:** Here we are inspecting the details about the data which we have.
#
# 3) **Data Cleaning and Processing :** In this section we have tried to remove the null values and for some of the columns we have replaced the null values with the appropriate values with reasonable assumptions.
#
# 3) **Analysis and Visualization :** In this section we have tried to explore all variables which can play an important role for the analysis. In the next parts we have tried to explore the effect of one over the other. In the next part we tried to answers our hypothetical questions.

# %% [markdown]
# ## **Library that is used in this project.**
#
# * **Numpy**
#
# * **Pandas**
#
# * **Matplotlib**
#
# * **Seaborn**

# %% [markdown]
# # **What is EDA?**
#
#  **EDA** stands for **“Exploratory Data Analysis “** EDA is applied to **investigate** the data and **summarize** the key **insights**.
# It will give you the basic understanding of your data, it’s **distribution**, null values and much more.
# You can either explore data using graphs or through some **python functions**.
#
# The following steps are involved in the **process of EDA:**
#
# * **Acquire and loading data**
# * **Inspecting the data**
# * **Understanding the variables**
# * **Cleaning dataset**
# * **Exploring and Visualizing Data**
# * **Analyzing relationships between variables**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ##**Loading the data.**

# %%
file_path = "/content/Customer Churn.csv"
df = pd.read_csv(file_path)
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# ##**Inspecting the data.**

# %%
df.shape
# Out:
# (7043, 21)

# %% [markdown]
# **The raw data contains 7043 rows (customers) and 21 columns (features).**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# **Here, we can see that there are total 21 columns.
# Where we have the customers account information - how long they’ve been a customer, contract, payment method, paperless billing, monthly charges, and total charges.**
#
#
# **Demographic info about customers - gender, age range, and if they have partners and dependents.**

# %% [markdown]
# ##**Here in info we can see that the 'Total Charges' is in object type but it should be in integer or float type.**

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
zero_tenure_rows = df[df['tenure'] == 0]

# %%
print("\nRows where 'tenure' is 0:")
print(zero_tenure_rows)
# Out:
# Rows where 'tenure' is 0:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# ...

# %% [markdown]
# ##**Due to zero tenure of the customer, some of the values in total charges is become blank. That is the reason why the total charges is in object type.**

# %%
df['TotalCharges'] = df['TotalCharges'].replace(" ", "0")  #replacing the NaN values into zeros.
df["TotalCharges"] = df['TotalCharges'].astype(float)      #changing total charges from object to float.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
#Checking if any null values are available in the dataset.
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# **So, there is no null value in the dataset.**

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.734304
# std         0.368612    24.559481       30.090047   2266.794470
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df.describe().T
# Out:
#                  count         mean          std    min     25%      50%  \
# SeniorCitizen   7043.0     0.162147     0.368612   0.00    0.00     0.00
# tenure          7043.0    32.371149    24.559481   0.00    9.00    29.00
# MonthlyCharges  7043.0    64.761692    30.090047  18.25   35.50    70.35
# TotalCharges    7043.0  2279.734304  2266.794470   0.00  398.55  1394.55
#
#                     75%      max
# SeniorCitizen      0.00     1.00
# tenure            55.00    72.00
# MonthlyCharges    89.85   118.75
# TotalCharges    3786.60  8684.80

# %% [markdown]
# **We can see that the average tenure of the customers are nearly 32 months with the average monthly charges of 64.76 dollors and total average charges is nearly about 2280 dollors.**

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#Checking if any duplicates value available in our data.

df["customerID"].duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##**As we can see that there are no duplicates value in our unique column and as well as in the whole data.**

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# **Here, as we can see that the seniorcitizen's column the value is in the form of 0 and 1.**
#
# 1 means the person is a senior citizen.
#
# 0 means the person is not a senior citizen.

# %%
#We are changing the value of senior citizen from 1 or 0 to "Yes" or "No".

def conv(value):
  if value == 0:
    return "Yes"
  else:
    return "No"

df["SeniorCitizen"] = df["SeniorCitizen"].apply(conv)

# %% [markdown]
# **Converted 0 and 1 values of senior citizen into yes/no to make it easier to understand.**

# %%
df.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female           Yes     Yes         No       1           No
# 1  5575-GNVDE    Male           Yes      No         No      34          Yes
# 2  3668-QPYBK    Male           Yes      No         No       2          Yes
# 3  7795-CFOCW    Male           Yes      No         No      45           No
# 4  9237-HQITU  Female           Yes      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ##**1. Let's find that how many customers have churned out?**

# %%
ax = sns.countplot(x = "Churn", data = df)
ax.bar_label(ax.containers[0])
plt.title("Count of Customers Churned")
plt.show()

# %% [markdown]
# **So, total 1869 number of customers have churned out and 5174 number of customers still continuing with the service.**

# %%
#percent of customers in terms of percentage.
gb = df.groupby("Churn").agg({"Churn": "count"})
plt.figure(figsize=(6,6))
plt.pie(gb["Churn"], labels = gb.index, autopct = "%1.2f%%", colors=['lavender', 'pink'] )
plt.title("Percentage of Churned Customers")
plt.show()

gb
# Out:
#        Churn
# Churn
# No      5174
# Yes     1869

# %% [markdown]
# **So, total 73.46% of customers have not churned and 26.54% of customers churned out.**

# %% [markdown]
# ##**How many customers are here according to gender?**

# %%
ax = sns.countplot(x = 'gender', data =df , hue ="Churn")
ax.bar_label(ax.containers[0])
plt.title("Churn by Gender")
plt.show()

# %% [markdown]
# **There are approx the same number of male and female customers.**

# %%
ax = sns.countplot(x = 'SeniorCitizen', data =df , hue ="Churn")
ax.bar_label(ax.containers[0])
plt.title("Churn by Senior Citizen")
plt.show()

# %% [markdown]
# **Observed that- Very less number of Senior Citizens are here and the percentage of churned values of senior citizen is very high.**

# %% [markdown]
# ##**what is the ratio between Senior Citizens and others in our company ?**

# %%
senior_counts = df['SeniorCitizen'].value_counts(normalize=True) * 100

print("Percentage of Senior Citizens and others:\n", senior_counts)
# Out:
# Percentage of Senior Citizens and others:
#  SeniorCitizen
# Yes    83.785319
# No     16.214681
# Name: proportion, dtype: float64

# %% [markdown]
# **SeniorCitizen ratio is 16.2 %**
#
# **non-SeniorCitizen ratio is 83.8 %**

# %%
plt.figure(figsize=(8, 8))

senior_counts.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=['lavender', 'lightblue'], shadow=True, wedgeprops={'edgecolor': 'white', 'linewidth': 6})

plt.title('Senior Citizen Distribution')

plt.ylabel('')

plt.show()

# %%
plt.figure(figsize=(10, 6))

ax = sns.countplot(data=df, x='SeniorCitizen', hue='Churn', dodge=True, edgecolor='white', linewidth=5, palette=['skyblue', 'pink'])

ax.bar_label(ax.containers[0])

plt.title('Senior Citizen Distribution with Churn Status')

plt.xlabel('Senior Citizen (0 = No, 1 = Yes)')

plt.ylabel('Count')



plt.legend(title='Churn Status', shadow=True, loc='upper right')

plt.show()

# %% [markdown]
# **Comparatively a greater number of customers in Senior Citizens have been churned out.**

# %%
plt.figure(figsize = (9,4))
sns.histplot(x = "tenure", data = df, hue = "Churn", bins = 72)
plt.show()

# %% [markdown]
# **Customers who had taken the service for a short period of time would have churned out while customers who have used our service for a long period of time have been stayed.**

# %%
ax = sns.countplot(x = "Contract", data = df)
ax.bar_label(ax.containers[0])
plt.show()

# %%
ax = sns.countplot(x = "Contract", data = df, hue = "Churn")
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# **Maximum the customers who have taken the month to month service have been churned out, followed by one year contract and then followed by two year of contract. We should asked the customers to go for the minimun one year of contract.**

# %%
churned_counts = df['Contract'].value_counts(normalize=True) * 100

print("Percentage of Churned Customers on the basis of Contract and others:\n", churned_counts)
# Out:
# Percentage of Churned Customers on the basis of Contract and others:
#  Contract
# Month-to-month    55.019168
# Two year          24.066449
# One year          20.914383
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(8, 8))

churned_counts.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=['lavender', 'skyblue', 'lightblue'], shadow=True, wedgeprops={'edgecolor': 'white', 'linewidth': 6})

plt.title('Churned by Contract')

plt.ylabel('')

plt.show()

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
payment_method = df['PaymentMethod'].value_counts(normalize=True)*100
print(payment_method)
# Out:
# PaymentMethod
# Electronic check             33.579441
# Mailed check                 22.887974
# Bank transfer (automatic)    21.922476
# Credit card (automatic)      21.610109
# Name: proportion, dtype: float64

# %%
plt.figure(figsize = (10,8))
ax = sns.histplot(x = "PaymentMethod", data = df)
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# **Mostly people likely to pay by Electronic Check followed by Mailed Check, Bank Transfer and Credit Card.**
#
# **Electronic check-**             **33.57%**
#
# **Mailed check-**                **22.88%**
#
# **Bank transfer (automatic)-    21.92%**
#
# **Credit card (automatic)-      21.61%**

# %%
columns_to_plot = [
    'PhoneService', 'MultipleLines', 'InternetService',
    'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
    'StreamingTV', 'StreamingMovies'
]

# Create a figure with subplots (3 rows, 3 columns for the 9 features)
fig, axes = plt.subplots(3, 3, figsize=(12, 8))

# Flatten the axes array to easily loop through
axes = axes.flatten()

# Loop through the columns and create a countplot for each
for i, column in enumerate(columns_to_plot):
    sns.countplot(x=column, data=df, hue="Churn", ax=axes[i])
    axes[i].set_title(f"Churn by {column}")
    axes[i].set_xlabel(column)
    axes[i].set_ylabel("Count")

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()
